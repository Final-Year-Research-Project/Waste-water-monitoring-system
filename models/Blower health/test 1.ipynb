# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Load the dataset
data = pd.read_csv('your_dataset.csv')  # Replace with your actual file path

# Separate features (X) and target variable (y)
X = data.drop('Blower Health (%)', axis=1)
y = data['Blower Health (%)']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-85df52ec7a36> in <cell line: 2>()
#       1 # Load the dataset
# ----> 2 data = pd.read_csv('your_dataset.csv')  # Replace with your actual file path
#       3
#       4 # Separate features (X) and target variable (y)
#       5 X = data.drop('Blower Health (%)', axis=1)
#
# NameError: name 'pd' is not defined
